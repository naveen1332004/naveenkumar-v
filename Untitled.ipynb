# %%
import os
import numpy as np
import pickle as pkl
from numpy.linalg import norm
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPool2D
import tensorflow as tf

# Ensure your dataset is in a folder called "images"
image_folder = 'images'
filenames = [os.path.join(image_folder, file) for file in os.listdir(image_folder) if file.endswith(('jpg', 'jpeg', 'png'))]

print(f"Number of images: {len(filenames)}")

# Load the ResNet50 model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
model = tf.keras.models.Sequential([base_model, GlobalMaxPool2D()])
model.summary()

# Function to extract features
def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_preprocessed = preprocess_input(img_array)
    features = model.predict(img_preprocessed).flatten()
    return features / norm(features)

# Extract features for all images
features = [extract_features(file, model) for file in filenames]

# Save the features and filenames
os.makedirs('Fashion Recommendation', exist_ok=True)
with open('Fashion Recommendation/Images_features.pkl', 'wb') as f:
    pkl.dump(features, f)
with open('Fashion Recommendation/filenames.pkl', 'wb') as f:
    pkl.dump(filenames, f)

print("Feature extraction complete and files saved!")
# Out:
# Number of images: 44441
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 2048)           │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# ...
